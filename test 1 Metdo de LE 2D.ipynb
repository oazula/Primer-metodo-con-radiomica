# %% [markdown]
# # Iterative Radiomics-Guided Region Growing Algorithm

# %% [markdown]
# ## Objective
#
# Implement an iterative region growing algorithm using voxel-based PyRadiomics features on SPECT tumor images.
#
# ## Algorithm Overview
#
# 1. **Load SPECT DICOM Study**: Import full 3D DICOM series using SimpleITK
# 2. **Extract & Display Coronal Slice**: Select a specific coronal plane for analysis
# 3. **Define Working ROI**: Crop the coronal slice to the region of interest
# 4. **Create Initial Lesion Mask**: Apply intensity thresholding to identify potential lesion
# 5. **Compute Reference Radiomic Map**: Extract voxel-based Median map inside initial ROI (ROI0)
# 6. **Establish Statistical Limits**: Use ROI0 distribution as fixed reference (mean ± k*std)
# 7. **Iterative Region Growing**:
#    - Dilate current ROI to generate candidate voxels (corona)
#    - Compute voxel-based Median for dilated region
#    - Classify each voxel: accept if within statistical bounds
#    - Update ROI with accepted voxels
#    - Repeat for N iterations
# 8. **Generate Results & Visualizations**
#
# ## Key Implementation Details
#
# - **Radiomic Feature**: `firstorder.Median` (voxel-based)
# - **Reference Distribution**: Fixed throughout all iterations
# - **PyRadiomics Coordinate Handling**: Automatic reconstruction from bounding-box to full-image coordinates
# - **Configurable Parameters**: Threshold percentage, k-value, number of iterations

# %%
# ============================================================================== 
# 1. IMPORTS & SETUP
# ==============================================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.patches as patches
import SimpleITK as sitk
from pathlib import Path
from radiomics.glcm import RadiomicsGLCM
import pydicom

# %% [markdown]
# ## Variable parameters
#
# ### 1. **Threshold**
# ### 2. **k_value**
# ### 3. **Caracteristica radiomica**

# %%
# ==================================================================================================
# 2. CONFIGURATION & PARAMETERS
# ==================================================================================================

# Data paths
DATA_DIR = Path("PSMAB37")
SPECT_DIR = DATA_DIR / "SPECT"

# Imaging parameters
CORONAL_SLICE = 137
ROI_CROP = (220, 140)        # (row_start, col_start)

# Thresholding parameters
THRESHOLD_PERCENTILE = 0.65  # Initial ROI = 65% of maximum intensity

# --------------------------------------------------------------------------------------------------
# Local Entropy / GLCM parameters
# --------------------------------------------------------------------------------------------------

LE_RELATIVE_THRESHOLD = 0.35
GLCM_FORCE_2D = True
GLCM_FORCE_2D_DIMENSION = 0

# Preserve backward-compatible labels for notebook cells that still print them.
FEATURE_CLASS = "custom"
FEATURE_NAME = "LocalEntropy"
FEATURE_KEY = f"{FEATURE_CLASS}_{FEATURE_NAME}"
GROWING_METHOD = "directional"
ACCEPTANCE_METHOD = "relative"
EPSILON = LE_RELATIVE_THRESHOLD
THRESHOLD_PERCENT = 100.0 * LE_RELATIVE_THRESHOLD

# --------------------------------------------------------------------------------------------------
# PyRadiomics settings used only to build the GLCM matrices for custom Local Entropy
# --------------------------------------------------------------------------------------------------

KERNEL_RADIUS = 1
DISTANCES = [1]
WEIGHTING_NORM = None
NORMALIZE = False
REMOVE_OUTLIERS = None
BIN_WIDTH = 25

GLCM_SETTINGS = {
    "binWidth": BIN_WIDTH,
    "kernelRadius": KERNEL_RADIUS,
    "distances": DISTANCES,
    "weightingNorm": WEIGHTING_NORM,
    "normalize": NORMALIZE,
    "force2D": GLCM_FORCE_2D,
    "force2Ddimension": GLCM_FORCE_2D_DIMENSION,
    "symmetricalGLCM": True,
}

if REMOVE_OUTLIERS is not None:
    GLCM_SETTINGS["removeOutliers"] = REMOVE_OUTLIERS

# --------------------------------------------------------------------------------------------------
# Growing control
# --------------------------------------------------------------------------------------------------

MAX_DILATIONS = 20

# Backward-compatible alias kept for older cells that may still reference it.
NUM_ITERATIONS = MAX_DILATIONS

print("Configuration loaded:")
print(f"  - SPECT directory: {SPECT_DIR}")
print(f"  - Coronal slice: {CORONAL_SLICE}")
print(f"  - ROI crop offset: {ROI_CROP}")
print(f"  - Local Entropy relative threshold: {LE_RELATIVE_THRESHOLD}")
print(f"  - GLCM force2D: {GLCM_FORCE_2D}")
print(f"  - GLCM force2Ddimension: {GLCM_FORCE_2D_DIMENSION}")
print(f"  - MAX_DILATIONS: {MAX_DILATIONS}")
# Out:
# Configuration loaded:
#   - SPECT directory: PSMAB37\SPECT
#   - Coronal slice: 137
#   - ROI crop offset: (220, 140)
#   - Local Entropy relative threshold: 0.35
#   - GLCM force2D: True
#   - GLCM force2Ddimension: 0
#   - MAX_DILATIONS: 20

# %%
# ==============================================================================
# PyRadiomics extraction parameters
# ==============================================================================

KERNEL_RADIUS = 1           # Radius for voxel-based extraction
DISTANCES = [1]             # Neighbor distances for texture matrices
WEIGHTING_NORM = None       # None, "manhattan", "euclidean", "infinity"

# Optional preprocessing
NORMALIZE = False
REMOVE_OUTLIERS = None

# Gray level discretization
BIN_WIDTH = 25              # Fixed Bin Size (default)

# Voxel-based extraction
KERNEL_RADIUS = 1           # Default
MASKED_KERNEL = True        # Default

# Texture computation
DISTANCES = [1]             # Default
WEIGHTING_NORM = None       # Default

# Image preprocessing
NORMALIZE = False           # Default
REMOVE_OUTLIERS = None      # Default

# Resampling
RESAMPLED_PIXEL_SPACING = None   # Default
INTERPOLATOR = sitk.sitkBSpline  # Default

# %% [markdown]
# ## Stage 1: Data Loading & Preparation

# %%
def _build_sitk_roi_image(roi_img, roi_mask):
    img_3d = roi_img[np.newaxis, :, :].astype(np.float32)
    mask_3d = roi_mask[np.newaxis, :, :].astype(np.uint8)
    sitk_img = sitk.GetImageFromArray(img_3d)
    sitk_mask = sitk.GetImageFromArray(mask_3d)
    return sitk_img, sitk_mask


def _extract_glcm_matrices(roi_img, roi_mask):
    sitk_img, sitk_mask = _build_sitk_roi_image(roi_img, roi_mask)
    calculator = RadiomicsGLCM(sitk_img, sitk_mask, **GLCM_SETTINGS)
    calculator._initCalculation()
    
    #
    glcm_array = calculator.P_glcm

    print("Type of P_glcm:", type(glcm_array))
    print("Shape of P_glcm:", glcm_array.shape)
    print("Number of dimensions:", glcm_array.ndim)

    for direction_index in range(glcm_array.shape[3]):
        matrix = glcm_array[0, :, :, direction_index]

        print(f"\nDirection {direction_index}")
        print("Shape:", matrix.shape)
        print("Sum:", matrix.sum())
        print("Non-zero elements:", np.count_nonzero(matrix))

    print(
    "\nAre direction 0 and direction 1 identical?",
    np.allclose(
        glcm_array[0, :, :, 0],
        glcm_array[0, :, :, 1]
    )
)
    #
    glcm_array = np.asarray(calculator.P_glcm, dtype=float)
    if glcm_array.ndim == 3:
        glcm_array = glcm_array[..., np.newaxis]

    directional_matrices = []
    directional_local_entropies = []

    for direction_index in range(glcm_array.shape[-1]):
        matrix = np.asarray(glcm_array[0, :, :, direction_index], dtype=float)
        directional_matrices.append(matrix.copy())

        valid_entries = np.isfinite(matrix) & (matrix > 0)
        if np.any(valid_entries):
            directional_local_entropy = float(np.sum(matrix[valid_entries] * np.log(matrix[valid_entries]))) #Equation for local entropy
        else:
            directional_local_entropy = np.nan
        directional_local_entropies.append(directional_local_entropy)

    directional_local_entropies = np.asarray(directional_local_entropies, dtype=float)
    if np.all(np.isnan(directional_local_entropies)):
        roi_local_entropy = np.nan
    else:
        roi_local_entropy = float(np.nanmean(directional_local_entropies))

    return {
        "roi_local_entropy": roi_local_entropy,
        "directional_local_entropies": directional_local_entropies,
        "directional_glcm_matrices": directional_matrices,
        "glcm_matrix_array": glcm_array,
        "glcm_matrix_count": len(directional_matrices),
        "calculator": calculator,
    }


def _relative_difference(trial_value, reference_value):
    denominator = abs(reference_value)
    if denominator == 0:
        denominator = np.finfo(float).eps
    return abs(trial_value - reference_value) / denominator


def _shift_roi_one_pixel(current_roi, direction):
    new_pixels = np.zeros_like(current_roi, dtype=bool)

    if direction == "right":
        new_pixels[:, 1:] = current_roi[:, :-1]
    elif direction == "left":
        new_pixels[:, :-1] = current_roi[:, 1:]
    elif direction == "down":
        new_pixels[1:, :] = current_roi[:-1, :]
    elif direction == "up":
        new_pixels[:-1, :] = current_roi[1:, :]
    else:
        raise ValueError(f"Unknown growth direction: {direction}")

    new_pixels &= ~current_roi
    trial_roi = current_roi | new_pixels
    return trial_roi, new_pixels


def _evaluate_direction(current_roi, direction, roi0_le):
    trial_roi, new_pixels = _shift_roi_one_pixel(current_roi, direction)
    if not np.any(new_pixels):
        return {
            "direction": direction,
            "active_at_start": True,
            "accepted": False,
            "deactivated": True,
            "deactivation_reason": "No new pixels available in this direction",
            "current_roi": current_roi.copy(),
            "trial_roi": trial_roi.copy(),
            "new_pixels": new_pixels.copy(),
            "roi0_le": roi0_le,
            "trial_le": np.nan,
            "relative_difference": np.nan,
            "directional_local_entropies": np.array([], dtype=float),
            "directional_glcm_matrices": [],
            "glcm_matrix_count": 0,
        }

    entropy_data = _extract_glcm_matrices(roi_img, trial_roi)
    
    #
    if direction in ["right", "left"]:
        print(
        f"{direction} trial LE:",
        entropy_data["roi_local_entropy"]
    )

        print(
        f"{direction} GLCM[0] sum:",
        entropy_data["directional_glcm_matrices"][0].sum()
    )

        print(
        f"{direction} GLCM[0] nonzero:",
        np.count_nonzero(
            entropy_data["directional_glcm_matrices"][0]
        )
    )
    #   
        
    trial_le = entropy_data["roi_local_entropy"]
    relative_difference = _relative_difference(trial_le, roi0_le)
    accepted = bool(np.isfinite(relative_difference) and relative_difference < LE_RELATIVE_THRESHOLD)
    print("Direction:", direction)
    print("Current ROI pixels:", np.sum(current_roi))
    print("New pixels:", np.sum(new_pixels))
    print("Trial ROI pixels:", np.sum(trial_roi))
    return {
        "direction": direction,
        "active_at_start": True,
        "accepted": accepted,
        "deactivated": not accepted,
        "deactivation_reason": None if accepted else "Relative difference reached or exceeded threshold",
        "current_roi": current_roi.copy(),
        "trial_roi": trial_roi.copy(),
        "new_pixels": new_pixels.copy(),
        "roi0_le": roi0_le,
        "trial_le": trial_le,
        "relative_difference": relative_difference,
        "directional_local_entropies": entropy_data["directional_local_entropies"].copy(),
        "directional_glcm_matrices": [matrix.copy() for matrix in entropy_data["directional_glcm_matrices"]],
        "glcm_matrix_count": entropy_data["glcm_matrix_count"],
        "glcm_matrix_array": entropy_data["glcm_matrix_array"].copy(),
    }


def _combine_accepted_expansions(current_roi, direction_records):
    next_roi = current_roi.copy()
    combined_new_pixels = np.zeros_like(current_roi, dtype=bool)

    for record in direction_records:
        if record["accepted"]:
            combined_new_pixels |= record["new_pixels"]

    next_roi |= combined_new_pixels
    return next_roi, combined_new_pixels


def run_directional_region_growing(roi0, roi0_le):
    current_roi = roi0.copy()
    active_directions = {
        "right": True,
        "left": True,
        "down": True,
        "up": True,
    }

    iteration_history = []
    directional_history = []
    stopping_reason = f"Reached MAX_DILATIONS ({MAX_DILATIONS})"

    print(f"Starting directional Local Entropy growing ({MAX_DILATIONS} iterations max)...\n")

    for iteration in range(1, MAX_DILATIONS + 1):
        current_iteration_record = {
            "iteration": iteration,
            "roi_current": current_roi.copy(),
            "roi_current_le": np.nan,
            "direction_trials": {},
        }
        direction_records = []

        for direction in ("right", "left", "down", "up"):
            if not active_directions[direction]:
                skipped_record = {
                    "iteration": iteration,
                    "direction": direction,
                    "active_at_start": False,
                    "accepted": False,
                    "deactivated": True,
                    "deactivation_reason": "Direction already permanently deactivated",
                    "current_roi": current_roi.copy(),
                    "trial_roi": current_roi.copy(),
                    "new_pixels": np.zeros_like(current_roi, dtype=bool),
                    "roi0_le": roi0_le,
                    "trial_le": np.nan,
                    "relative_difference": np.nan,
                    "directional_local_entropies": np.array([], dtype=float),
                    "directional_glcm_matrices": [],
                    "glcm_matrix_count": 0,
                }
                current_iteration_record["direction_trials"][direction] = skipped_record
                directional_history.append(skipped_record)
                continue

            direction_record = _evaluate_direction(current_roi, direction, roi0_le)
            direction_record["iteration"] = iteration
            direction_record["active_at_start"] = True
            direction_record["roi_after_acceptance"] = None

            if not direction_record["accepted"]:
                active_directions[direction] = False

            current_iteration_record["direction_trials"][direction] = direction_record
            direction_records.append(direction_record)
            directional_history.append(direction_record)

        accepted_records = [record for record in direction_records if record["accepted"]]
        next_roi, combined_new_pixels = _combine_accepted_expansions(current_roi, direction_records)

        if np.any(combined_new_pixels):
            next_roi_le_data = _extract_glcm_matrices(roi_img, next_roi)
            next_roi_le = next_roi_le_data["roi_local_entropy"]
        else:
            next_roi_le = np.nan

        current_iteration_record.update(
            {
                "accepted_directions": [record["direction"] for record in accepted_records],
                "rejected_directions": [
                    record["direction"]
                    for record in direction_records
                    if not record["accepted"] and record["deactivation_reason"] is not None
                ],
                "inactive_directions": [
                    direction for direction, is_active in active_directions.items() if not is_active
                ],
                "combined_new_pixels": combined_new_pixels.copy(),
                "roi_after": next_roi.copy(),
                "roi_after_le": next_roi_le,
                "accepted_direction_count": len(accepted_records),
                "rejected_direction_count": sum(
                    1 for record in direction_records if (not record["accepted"]) and record["active_at_start"]
                ),
                "active_direction_count": sum(active_directions.values()),
                "roi_size_before": int(current_roi.sum()),
                "roi_size_after": int(next_roi.sum()),
                "new_pixel_count": int(combined_new_pixels.sum()),
                "roi0_le": roi0_le,
                "relative_difference_from_roi0": _relative_difference(next_roi_le, roi0_le) if np.isfinite(next_roi_le) else np.nan,
            }
        )

        iteration_history.append(current_iteration_record)

        print(
            f"Iter {iteration:2d}: ROI {current_roi.sum():4d} -> {next_roi.sum():4d} | "
            f"Accepted dirs: {len(accepted_records):d} | Active dirs: {sum(active_directions.values()):d} | "
            f"New pixels: {combined_new_pixels.sum():4d}"
        )

        if len(accepted_records) == 0:
            stopping_reason = "No accepted directional expansion in this iteration"
            break

        current_roi = next_roi

        if sum(active_directions.values()) == 0:
            stopping_reason = "All four directions were permanently deactivated"
            break

    roi_final = current_roi.copy()
    return roi_final, iteration_history, directional_history, stopping_reason


print("✓ Directional Local Entropy helpers defined")
# Out:
# ✓ Directional Local Entropy helpers defined

# %%
# Load SPECT DICOM series
reader = sitk.ImageSeriesReader()
files = reader.GetGDCMSeriesFileNames(str(SPECT_DIR))
reader.SetFileNames(files)
spect_img = reader.Execute()# este es el objeto de imagen de SPECT en SimpleITK

spect_array = sitk.GetArrayFromImage(spect_img)# este es la imagen de SPECT en un array de numpy

print(f" SPECT series loaded")
print(f"  - Shape: {spect_array.shape}")#Formato: (z, y, x) para imágenes 3D
print(f"  - Size: {spect_img.GetSize()}")#Formato: (x, y, z) para imágenes 3D
print(f"  - Spacing: {spect_img.GetSpacing()}") #Devuelve el tamaño físico de cada voxel en milímetros (x_spacing, y_spacing, z_spacing)
print(f"  - Range: [{spect_array.min():.2f}, {spect_array.max():.2f}]") #Muestra los valores mínimo y máximo de intensidad de la imagen.
# Out:
#  SPECT series loaded
#   - Shape: (299, 256, 256)
#   - Size: (256, 256, 299)
#   - Spacing: (2.734375, 2.734375, 3.270000022529765)
#   - Range: [0.00, 52344.30]

# %%
# Extract and display coronal slice
coronal_raw = spect_array[:, CORONAL_SLICE, :]#
coronal_vis = np.fliplr(np.rot90(coronal_raw, 2))# SE ROTAN 180 GRADOS Y SE VOLTEA HORIZONTALMENTE PARA QUE LA IMAGEN CORONAL SE VISUALICE CORRECTAMENTE


# Crop to working region
roi_img = coronal_vis[ROI_CROP[0]:, ROI_CROP[1]:]# se recorta la imagen coronal para obtener la región de interés (ROI) a partir de las coordenadas especificadas en ROI_CROP

print(f" Coronal slice extracted and processed")
print(f"  - Coronal slice index: {CORONAL_SLICE}")
print(f"  - Full coronal shape: {coronal_vis.shape}")
print(f"  - Working ROI shape: {roi_img.shape}")
print(f"  - ROI intensity range: [{roi_img.min():.2f}, {roi_img.max():.2f}]")

# Visualize working ROI
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Full coronal image
axes[0].imshow(
    coronal_vis,
    cmap="hot",
    vmin=0,
    vmax=np.percentile(coronal_vis, 99)
)

# Coordinate grid
axes[0].set_xticks(np.arange(0, coronal_vis.shape[1], 20))
axes[0].set_yticks(np.arange(0, coronal_vis.shape[0], 20))
axes[0].grid(True, alpha=0.3)

# ROI rectangle
roi_rect = patches.Rectangle(
    (ROI_CROP[1], ROI_CROP[0]),               # (x, y)
    coronal_vis.shape[1] - ROI_CROP[1],      # width
    coronal_vis.shape[0] - ROI_CROP[0],      # height
    linewidth=2,
    edgecolor="cyan",
    facecolor="none",
    label="Working ROI"
)

axes[0].add_patch(roi_rect)

axes[0].set_title("Full Coronal Slice with ROI Bounds")
axes[0].legend()

# Cropped ROI
axes[1].imshow(
    roi_img,
    cmap="hot",
    vmin=0,
    vmax=np.percentile(roi_img, 99)
)

axes[1].set_title("Working ROI (Cropped Region)")
axes[1].axis("on")

plt.tight_layout()
plt.show()
# Out:
#  Coronal slice extracted and processed
#   - Coronal slice index: 137
#   - Full coronal shape: (299, 256)
#   - Working ROI shape: (79, 116)
#   - ROI intensity range: [0.00, 19446.12]

# %% [markdown]
# ### ____________________________________________________________________________-

# %%
# ==============================================================================
# ! Stage 1.5: Load Manual Segmentation (DICOM SEG)
# ==============================================================================

SEG_PATH = DATA_DIR / "SEGMENTATIONS" / "1-1.dcm"

def load_manual_segmentation(
    seg_path,
    spect_dir,
    spect_array,
    coronal_slice,
    roi_crop
):
    """
    Load DICOM SEG, reconstruct full 3D segmentation volume,
    extract the same coronal plane used by the algorithm,
    and apply identical visualization transforms and ROI crop.
    """

    # Load SEG object
    seg = pydicom.dcmread(str(seg_path))
    seg_array = seg.pixel_array.astype(np.uint8)

    # Build UID -> slice index map from SPECT series
    spect_files = sorted(Path(spect_dir).glob("*.dcm"))

    uid_to_slice = {}

    for idx, f in enumerate(spect_files):

        ds = pydicom.dcmread(
            str(f),
            stop_before_pixels=True
        )

        uid_to_slice[ds.SOPInstanceUID] = idx

    # Determine which SPECT slice corresponds to each SEG frame
    seg_slices = []

    for frame in seg.PerFrameFunctionalGroupsSequence:

        uid = (
            frame.DerivationImageSequence[0]
            .SourceImageSequence[0]
            .ReferencedSOPInstanceUID
        )

        if uid in uid_to_slice:
            seg_slices.append(uid_to_slice[uid])

    # Reconstruct full 3D segmentation volume
    manual_mask_3d = np.zeros_like(
        spect_array,
        dtype=np.uint8
    )

    for frame_idx, spect_idx in enumerate(seg_slices):
        manual_mask_3d[spect_idx] = seg_array[frame_idx]

    # Extract same coronal plane
    manual_coronal_raw = manual_mask_3d[:, coronal_slice, :]

    # Apply same visualization orientation
    manual_coronal_vis = np.flipud(
        np.fliplr(
            np.rot90(manual_coronal_raw, 2)
        )
    )

    # Apply same ROI crop
    manual_mask_roi = manual_coronal_vis[
        roi_crop[0]:,
        roi_crop[1]:
    ]

    return (
        manual_mask_3d,
        manual_coronal_vis,
        manual_mask_roi
    )

# Load manual segmentation
manual_mask_3d, manual_coronal_vis, manual_mask_roi = (
    load_manual_segmentation(
        SEG_PATH,
        SPECT_DIR,
        spect_array,
        CORONAL_SLICE,
        ROI_CROP
    )
)

print("✓ Manual segmentation loaded")
print(f"  - Segmented voxels (3D): {manual_mask_3d.sum()}")
print(f"  - Segmented pixels in ROI: {manual_mask_roi.sum()}")

# Visual verification

plt.figure(figsize=(8,8))

plt.imshow(
    roi_img,
    cmap="gray",
    vmin=0,
    vmax=np.percentile(roi_img, 99)
)

plt.contour(
    manual_mask_roi,
    colors="lime",
    linewidths=2
)

plt.title("Manual Segmentation Overlay")
plt.show()
# Out:
# ✓ Manual segmentation loaded
#   - Segmented voxels (3D): 4828
#   - Segmented pixels in ROI: 318

# %% [markdown]
# ### _____________________________________________________________________________________________

# %% [markdown]
# ## Stage 2: Initial Lesion Mask (ROI0)

# %%
# Create initial lesion mask (ROI0)
threshold = THRESHOLD_PERCENTILE * roi_img.max() 
mask0 = roi_img > threshold # todo voxel con intensidad mayor al umbral se considera parte de la lesión y se marca como True en la máscara binaria mask0

print(f" Initial mask (ROI0) created")
print(f"  - Threshold: {THRESHOLD_PERCENTILE * 100:.0f}% of max = {threshold:.2f}")
print(f"  - Mask size: {mask0.sum()} voxels")

# Visualize initial mask
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

axes[0].imshow(roi_img, cmap="gray", vmin=0, vmax=np.percentile(roi_img, 99))
axes[0].set_title("Original ROI")
axes[0].axis('off')

axes[1].imshow(mask0, cmap="hot")
axes[1].set_title(f"ROI0 Mask ({mask0.sum()} voxels)")
axes[1].axis('off')

axes[2].imshow(roi_img, cmap="gray", vmin=0, vmax=np.percentile(roi_img, 99))
axes[2].contour(mask0, colors='r', linewidths=2)
axes[2].set_title("ROI0 Contour on Original Image")
axes[2].axis('off')

plt.tight_layout()
plt.show()
# Out:
#  Initial mask (ROI0) created
#   - Threshold: 65% of max = 12639.98
#   - Mask size: 76 voxels

# %% [markdown]
# ## Stage 3: PyRadiomics Setup & Utility Functions

# %% [markdown]
# ## Initialize custom GLCM helper
#
# The notebook uses PyRadiomics GLCM matrices only as an intermediate step to compute the custom Local Entropy reference and all directional trial values.

# %%
# ==============================================================================
# Initialize PyRadiomics settings for custom Local Entropy via GLCM matrices
# ==============================================================================

print("✓ Custom Local Entropy setup ready")
print("  - PyRadiomics GLCM is used only to build directional GLCM matrices")
print(f"  - binWidth       = {GLCM_SETTINGS['binWidth']}")
print(f"  - kernelRadius   = {GLCM_SETTINGS['kernelRadius']}")
print(f"  - distances      = {GLCM_SETTINGS['distances']}")
print(f"  - weightingNorm  = {GLCM_SETTINGS['weightingNorm']}")
print(f"  - normalize      = {GLCM_SETTINGS['normalize']}")
print(f"  - force2D        = {GLCM_SETTINGS['force2D']}")
print(f"  - force2Ddim     = {GLCM_SETTINGS['force2Ddimension']}")
print(f"  - symmetricalGLCM = {GLCM_SETTINGS['symmetricalGLCM']}")
# Out:
# ✓ Custom Local Entropy setup ready
#   - PyRadiomics GLCM is used only to build directional GLCM matrices
#   - binWidth       = 25
#   - kernelRadius   = 1
#   - distances      = [1]
#   - weightingNorm  = None
#   - normalize      = False
#   - force2D        = True
#   - force2Ddim     = 0
#   - symmetricalGLCM = True

# %%
def reconstruct_voxel_map(result_dict, reference_shape, feature_key):
    """
    result_dict: diccionario de resultados de PyRadiomics que contiene la característica extraída y la bounding box
    reference_shape: la forma de la imagen original
    feature_key: clave de la característica en result_dict (ej. "original_firstorder_M
    
    Tomar el mapa radiomico (que viene en bounding box) y colocarlo de nuevo en 
    la imagen original. ME DA UN ARRAY CON el mapa radiomico voxel-based reubicado en el sistema original de la imagen (80×60), lo que 
    no esta en el bounding box esta llenos de ceros sin filtrar aun con la mascara
    """
    bbox_key = "diagnostics_Mask-original_BoundingBox"  # variable donde PyRadiomics guarda la bounding box
    if bbox_key not in result_dict:  # verifica que la bounding box esté presente en el resultado
        raise ValueError(f"Bounding box not found in result. Available keys: {result_dict.keys()}")  # lanza error si falta
    
    bbox = result_dict[bbox_key]  # extrae la tupla bounding box
    x, y, z, sx, sy, sz = bbox  # desempaqueta las coordenadas y tamaños del bounding box
    
    if feature_key not in result_dict:  # comprueba que la clave de la característica exista en el resultado
        raise ValueError(
            f"Feature key '{feature_key}' not found in result. Available keys: {list(result_dict.keys())}"
        )  # lanza error si la característica no está presente
    feature_img = result_dict[feature_key]  # obtiene la imagen SimpleITK correspondiente a la característica
    median_map = sitk.GetArrayFromImage(feature_img)[0]  # convierte la imagen a numpy y toma la primera (única) z-slice
    
    full_map = np.zeros(reference_shape, dtype=float)  # inicializa el mapa completo con ceros (float)
    
    h, w = median_map.shape  # obtiene alto y ancho del mapa dentro del bounding box
    x0 = x - 1  # convierte la coordenada x de 1-based (PyRadiomics) a 0-based (numpy)
    y0 = y - 1  # convierte la coordenada y de 1-based a 0-based
    
    full_map[
        y0:y0 + h,
        x0:x0 + w
    ] = median_map  # inserta el mapa extraído en la posición correspondiente del mapa completo
    
    return full_map, (x0, y0, h, w)  # devuelve el mapa reconstruido y la información de bounding box ajustada

print("✓ Utility function 'reconstruct_voxel_map' defined")  # confirma que la función ha sido definida
# Out:
# ✓ Utility function 'reconstruct_voxel_map' defined

# %% [markdown]
# ## Stage 4: Fixed Local Entropy Reference (ROI0)

# %%
# ==============================================================================
# Extract ROI0 fixed Local Entropy reference and directional GLCM matrices
# ==============================================================================

roi0_entropy_data = _extract_glcm_matrices(roi_img, mask0)
ROI0_LE = roi0_entropy_data["roi_local_entropy"]
ROI0_DIRECTIONAL_LE = roi0_entropy_data["directional_local_entropies"]
ROI0_DIRECTIONAL_GLCM_MATRICES = roi0_entropy_data["directional_glcm_matrices"]
ROI0_GLCM_MATRIX_COUNT = roi0_entropy_data["glcm_matrix_count"]

print(f"✓ ROI0 Local Entropy computed")
print(f"  - ROI0 voxels: {mask0.sum()}")
print(f"  - Directional GLCM matrices: {ROI0_GLCM_MATRIX_COUNT}")
print(f"  - ROI0_LE: {ROI0_LE:.6f}")
print("  - Directional Local Entropy values:")
for idx, value in enumerate(ROI0_DIRECTIONAL_LE, start=1):
    print(f"      [{idx}] {value:.6f}")

# Visualization
fig, axes = plt.subplots(1, 3, figsize=(16, 4))

axes[0].imshow(roi_img, cmap="gray", vmin=0, vmax=np.percentile(roi_img, 99))
axes[0].contour(mask0, colors='g', linewidths=2)
axes[0].set_title(f"ROI0 on Original Image\n({mask0.sum()} voxels)")
axes[0].axis('off')

axes[1].bar(np.arange(1, ROI0_GLCM_MATRIX_COUNT + 1), ROI0_DIRECTIONAL_LE, color='steelblue', edgecolor='k')
axes[1].axhline(ROI0_LE, color='crimson', linestyle='--', linewidth=2, label=f'ROI0_LE = {ROI0_LE:.4f}')
axes[1].set_title("Directional Local Entropy values")
axes[1].set_xlabel("GLCM matrix index")
axes[1].set_ylabel("Local Entropy")
axes[1].legend()
axes[1].grid(alpha=0.3, axis='y')

first_glcm_matrix = ROI0_DIRECTIONAL_GLCM_MATRICES[0] if ROI0_DIRECTIONAL_GLCM_MATRICES else np.zeros((1, 1), dtype=float)
im = axes[2].imshow(first_glcm_matrix, cmap="viridis")
axes[2].set_title("First directional GLCM matrix")
axes[2].set_xlabel("Gray level j")
axes[2].set_ylabel("Gray level i")
plt.colorbar(im, ax=axes[2], fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()
# Out:
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 63, 63, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (63, 63)
# Sum: 0.9999999999999999
# Non-zero elements: 94
#
# Direction 1
# Shape: (63, 63)
# Sum: 1.0
# Non-zero elements: 110
#
# Direction 2
# Shape: (63, 63)
# Sum: 1.0
# Non-zero elements: 104
#
# Direction 3
# Shape: (63, 63)
# Sum: 1.0
# Non-zero elements: 115
#
# Are direction 0 and direction 1 identical? False
# ✓ ROI0 Local Entropy computed
#   - ROI0 voxels: 76
#   - Directional GLCM matrices: 4
#   - ROI0_LE: -4.655901
#   - Directional Local Entropy values:
#       [1] -4.543295
#       [2] -4.700480
#       [3] -4.644391
#       [4] -4.735440

# %% [markdown]
# ## Stage 5: Iterative Directional Region Growing

# %%
# Iterative directional region growing with fixed ROI0 Local Entropy reference
roi_final, iteration_history, directional_history, stopping_reason = run_directional_region_growing(mask0, ROI0_LE)

# Preserve the legacy notebook variable name for downstream cells
history = iteration_history
results = iteration_history

# Flatten the per-iteration structure into a tabular summary
iteration_rows = []
for iteration_record in iteration_history:
    iteration_rows.append({
        "Iteration": iteration_record["iteration"],
        "ROI Size Before": iteration_record["roi_size_before"],
        "ROI Size After": iteration_record["roi_size_after"],
        "Accepted Directions": ", ".join(iteration_record["accepted_directions"]) if iteration_record["accepted_directions"] else "None",
        "Rejected Directions": ", ".join(iteration_record["rejected_directions"]) if iteration_record["rejected_directions"] else "None",
        "Active Directions": iteration_record["active_direction_count"],
        "New Pixels Added": iteration_record["new_pixel_count"],
        "ROI LE After": iteration_record["roi_after_le"],
        "Relative Difference From ROI0": iteration_record["relative_difference_from_roi0"],
        "ROI0_LE": iteration_record["roi0_le"],
    })

df_results = pd.DataFrame(iteration_rows)

directional_rows = []
for directional_record in directional_history:
    directional_rows.append({
        "Iteration": directional_record["iteration"],
        "Direction": directional_record["direction"],
        "Accepted": directional_record["accepted"],
        "Deactivated": directional_record["deactivated"],
        "Deactivation Reason": directional_record["deactivation_reason"],
        "ROI0_LE": directional_record["roi0_le"],
        "Trial LE": directional_record["trial_le"],
        "Relative Difference": directional_record["relative_difference"],
        "Directional GLCM Count": directional_record["glcm_matrix_count"],
        "New Pixels": int(directional_record["new_pixels"].sum()),
    })

df_directional_results = pd.DataFrame(directional_rows)

print("\n✓ Iterative directional growing completed!")
print(f"Stopping reason: {stopping_reason}")

print("\nIteration summary:")
print(df_results.to_string(index=False))

print("\nDirectional evaluation summary (first rows):")
print(df_directional_results.head(len(df_directional_results)).to_string(index=False))
# Out:
# Starting directional Local Entropy growing (20 iterations max)...
#
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 80, 80, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (80, 80)
# Sum: 1.0
# Non-zero elements: 124
#
# Direction 1
# Shape: (80, 80)
# Sum: 1.0
# Non-zero elements: 140
#
# Direction 2
# Shape: (80, 80)
# Sum: 0.9999999999999999
# Non-zero elements: 136
#
# Direction 3
# Shape: (80, 80)
# Sum: 0.9999999999999999
# Non-zero elements: 149
#
# Are direction 0 and direction 1 identical? False
# right trial LE: -4.917774580469958
# right GLCM[0] sum: 1.0
# right GLCM[0] nonzero: 124
# Direction: right
# Current ROI pixels: 76
# New pixels: 17
# Trial ROI pixels: 93
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 80, 80, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (80, 80)
# Sum: 1.0
# Non-zero elements: 124
#
# Direction 1
# Shape: (80, 80)
# Sum: 0.9999999999999999
# Non-zero elements: 140
#
# Direction 2
# Shape: (80, 80)
# Sum: 0.9999999999999999
# Non-zero elements: 136
#
# Direction 3
# Shape: (80, 80)
# Sum: 1.0
# Non-zero elements: 149
#
# Are direction 0 and direction 1 identical? False
# left trial LE: -4.917774580469958
# left GLCM[0] sum: 1.0
# left GLCM[0] nonzero: 124
# Direction: left
# Current ROI pixels: 76
# New pixels: 17
# Trial ROI pixels: 93
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 83, 83, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (83, 83)
# Sum: 1.0
# Non-zero elements: 142
#
# Direction 1
# Shape: (83, 83)
# Sum: 1.0
# Non-zero elements: 164
#
# Direction 2
# Shape: (83, 83)
# Sum: 1.0
# Non-zero elements: 150
#
# Direction 3
# Shape: (83, 83)
# Sum: 0.9999999999999999
# Non-zero elements: 153
#
# Are direction 0 and direction 1 identical? False
# Direction: down
# Current ROI pixels: 76
# New pixels: 21
# Trial ROI pixels: 97
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 83, 83, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (83, 83)
# Sum: 1.0
# Non-zero elements: 142
#
# Direction 1
# Shape: (83, 83)
# Sum: 1.0
# Non-zero elements: 164
#
# Direction 2
# Shape: (83, 83)
# Sum: 1.0
# Non-zero elements: 149
#
# Direction 3
# Shape: (83, 83)
# Sum: 0.9999999999999998
# Non-zero elements: 153
#
# Are direction 0 and direction 1 identical? False
# Direction: up
# Current ROI pixels: 76
# New pixels: 21
# Trial ROI pixels: 97
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 110, 110, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (110, 110)
# Sum: 1.0
# Non-zero elements: 208
#
# Direction 1
# Shape: (110, 110)
# Sum: 1.0
# Non-zero elements: 222
#
# Direction 2
# Shape: (110, 110)
# Sum: 0.9999999999999998
# Non-zero elements: 213
#
# Direction 3
# Shape: (110, 110)
# Sum: 1.0
# Non-zero elements: 217
#
# Are direction 0 and direction 1 identical? False
# Iter  1: ROI   76 ->  129 | Accepted dirs: 4 | Active dirs: 4 | New pixels:   53
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 128, 128, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (128, 128)
# Sum: 1.0
# Non-zero elements: 244
#
# Direction 1
# Shape: (128, 128)
# Sum: 1.0
# Non-zero elements: 258
#
# Direction 2
# Shape: (128, 128)
# Sum: 1.0
# Non-zero elements: 249
#
# Direction 3
# Shape: (128, 128)
# Sum: 1.0
# Non-zero elements: 255
#
# Are direction 0 and direction 1 identical? False
# right trial LE: -5.525720858420179
# right GLCM[0] sum: 1.0
# right GLCM[0] nonzero: 244
# Direction: right
# Current ROI pixels: 129
# New pixels: 19
# Trial ROI pixels: 148
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 127, 127, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (127, 127)
# Sum: 1.0
# Non-zero elements: 244
#
# Direction 1
# Shape: (127, 127)
# Sum: 0.9999999999999999
# Non-zero elements: 258
#
# Direction 2
# Shape: (127, 127)
# Sum: 1.0
# Non-zero elements: 249
#
# Direction 3
# Shape: (127, 127)
# Sum: 0.9999999999999999
# Non-zero elements: 255
#
# Are direction 0 and direction 1 identical? False
# left trial LE: -5.525720858420179
# left GLCM[0] sum: 1.0
# left GLCM[0] nonzero: 244
# Direction: left
# Current ROI pixels: 129
# New pixels: 19
# Trial ROI pixels: 148
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 126, 126, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (126, 126)
# Sum: 1.0
# Non-zero elements: 244
#
# Direction 1
# Shape: (126, 126)
# Sum: 1.0
# Non-zero elements: 262
#
# Direction 2
# Shape: (126, 126)
# Sum: 1.0
# Non-zero elements: 247
#
# Direction 3
# Shape: (126, 126)
# Sum: 1.0
# Non-zero elements: 251
#
# Are direction 0 and direction 1 identical? False
# Direction: down
# Current ROI pixels: 129
# New pixels: 18
# Trial ROI pixels: 147
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 126, 126, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (126, 126)
# Sum: 1.0
# Non-zero elements: 244
#
# Direction 1
# Shape: (126, 126)
# Sum: 1.0
# Non-zero elements: 262
#
# Direction 2
# Shape: (126, 126)
# Sum: 0.9999999999999999
# Non-zero elements: 247
#
# Direction 3
# Shape: (126, 126)
# Sum: 1.0
# Non-zero elements: 251
#
# Are direction 0 and direction 1 identical? False
# Direction: up
# Current ROI pixels: 129
# New pixels: 18
# Trial ROI pixels: 147
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 153, 153, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (153, 153)
# Sum: 1.0
# Non-zero elements: 304
#
# Direction 1
# Shape: (153, 153)
# Sum: 1.0
# Non-zero elements: 318
#
# Direction 2
# Shape: (153, 153)
# Sum: 1.0
# Non-zero elements: 311
#
# Direction 3
# Shape: (153, 153)
# Sum: 1.0
# Non-zero elements: 309
#
# Are direction 0 and direction 1 identical? False
# Iter  2: ROI  129 ->  178 | Accepted dirs: 4 | Active dirs: 4 | New pixels:   49
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 172, 172, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (172, 172)
# Sum: 0.9999999999999999
# Non-zero elements: 344
#
# Direction 1
# Shape: (172, 172)
# Sum: 1.0
# Non-zero elements: 357
#
# Direction 2
# Shape: (172, 172)
# Sum: 1.0
# Non-zero elements: 351
#
# Direction 3
# Shape: (172, 172)
# Sum: 1.0
# Non-zero elements: 351
#
# Are direction 0 and direction 1 identical? False
# right trial LE: -5.858113864233292
# right GLCM[0] sum: 0.9999999999999999
# right GLCM[0] nonzero: 344
# Direction: right
# Current ROI pixels: 178
# New pixels: 21
# Trial ROI pixels: 199
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 169, 169, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (169, 169)
# Sum: 1.0
# Non-zero elements: 344
#
# Direction 1
# Shape: (169, 169)
# Sum: 0.9999999999999999
# Non-zero elements: 358
#
# Direction 2
# Shape: (169, 169)
# Sum: 1.0
# Non-zero elements: 351
#
# Direction 3
# Shape: (169, 169)
# Sum: 1.0
# Non-zero elements: 351
#
# Are direction 0 and direction 1 identical? False
# left trial LE: -5.859081946887706
# left GLCM[0] sum: 1.0
# left GLCM[0] nonzero: 344
# Direction: left
# Current ROI pixels: 178
# New pixels: 21
# Trial ROI pixels: 199
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 169, 169, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (169, 169)
# Sum: 1.0
# Non-zero elements: 340
#
# Direction 1
# Shape: (169, 169)
# Sum: 1.0
# Non-zero elements: 360
#
# Direction 2
# Shape: (169, 169)
# Sum: 1.0
# Non-zero elements: 347
#
# Direction 3
# Shape: (169, 169)
# Sum: 1.0
# Non-zero elements: 345
#
# Are direction 0 and direction 1 identical? False
# Direction: down
# Current ROI pixels: 178
# New pixels: 19
# Trial ROI pixels: 197
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 168, 168, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (168, 168)
# Sum: 1.0
# Non-zero elements: 340
#
# Direction 1
# Shape: (168, 168)
# Sum: 1.0
# Non-zero elements: 359
#
# Direction 2
# Shape: (168, 168)
# Sum: 1.0
# Non-zero elements: 347
#
# Direction 3
# Shape: (168, 168)
# Sum: 1.0
# Non-zero elements: 343
#
# Are direction 0 and direction 1 identical? False
# Direction: up
# Current ROI pixels: 178
# New pixels: 19
# Trial ROI pixels: 197
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 193, 193, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (193, 193)
# Sum: 1.0
# Non-zero elements: 400
#
# Direction 1
# Shape: (193, 193)
# Sum: 0.9999999999999999
# Non-zero elements: 413
#
# Direction 2
# Shape: (193, 193)
# Sum: 1.0
# Non-zero elements: 407
#
# Direction 3
# Shape: (193, 193)
# Sum: 1.0
# Non-zero elements: 403
#
# Are direction 0 and direction 1 identical? False
# Iter  3: ROI  178 ->  228 | Accepted dirs: 4 | Active dirs: 4 | New pixels:   50
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 207, 207, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (207, 207)
# Sum: 1.0
# Non-zero elements: 444
#
# Direction 1
# Shape: (207, 207)
# Sum: 0.9999999999999999
# Non-zero elements: 457
#
# Direction 2
# Shape: (207, 207)
# Sum: 1.0
# Non-zero elements: 451
#
# Direction 3
# Shape: (207, 207)
# Sum: 1.0
# Non-zero elements: 449
#
# Are direction 0 and direction 1 identical? False
# right trial LE: -6.1078735087240235
# right GLCM[0] sum: 1.0
# right GLCM[0] nonzero: 444
# Direction: right
# Current ROI pixels: 228
# New pixels: 23
# Trial ROI pixels: 251
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 208, 208, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (208, 208)
# Sum: 1.0
# Non-zero elements: 444
#
# Direction 1
# Shape: (208, 208)
# Sum: 0.9999999999999999
# Non-zero elements: 457
#
# Direction 2
# Shape: (208, 208)
# Sum: 1.0
# Non-zero elements: 451
#
# Direction 3
# Shape: (208, 208)
# Sum: 0.9999999999999999
# Non-zero elements: 449
#
# Are direction 0 and direction 1 identical? False
# left trial LE: -6.1078735087240235
# left GLCM[0] sum: 1.0
# left GLCM[0] nonzero: 444
# Direction: left
# Current ROI pixels: 228
# New pixels: 23
# Trial ROI pixels: 251
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 207, 207, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (207, 207)
# Sum: 1.0
# Non-zero elements: 440
#
# Direction 1
# Shape: (207, 207)
# Sum: 1.0000000000000002
# Non-zero elements: 459
#
# Direction 2
# Shape: (207, 207)
# Sum: 0.9999999999999999
# Non-zero elements: 447
#
# Direction 3
# Shape: (207, 207)
# Sum: 0.9999999999999998
# Non-zero elements: 443
#
# Are direction 0 and direction 1 identical? False
# Direction: down
# Current ROI pixels: 228
# New pixels: 21
# Trial ROI pixels: 249
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 207, 207, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (207, 207)
# Sum: 1.0
# Non-zero elements: 440
#
# Direction 1
# Shape: (207, 207)
# Sum: 0.9999999999999999
# Non-zero elements: 459
#
# Direction 2
# Shape: (207, 207)
# Sum: 0.9999999999999999
# Non-zero elements: 447
#
# Direction 3
# Shape: (207, 207)
# Sum: 0.9999999999999998
# Non-zero elements: 440
#
# Are direction 0 and direction 1 identical? False
# Direction: up
# Current ROI pixels: 228
# New pixels: 21
# Trial ROI pixels: 249
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 226, 226, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (226, 226)
# Sum: 1.0
# Non-zero elements: 504
#
# Direction 1
# Shape: (226, 226)
# Sum: 1.0
# Non-zero elements: 517
#
# Direction 2
# Shape: (226, 226)
# Sum: 1.0
# Non-zero elements: 511
#
# Direction 3
# Shape: (226, 226)
# Sum: 1.0
# Non-zero elements: 504
#
# Are direction 0 and direction 1 identical? False
# Iter  4: ROI  228 ->  282 | Accepted dirs: 4 | Active dirs: 4 | New pixels:   54
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 241, 241, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (241, 241)
# Sum: 1.0
# Non-zero elements: 552
#
# Direction 1
# Shape: (241, 241)
# Sum: 1.0000000000000002
# Non-zero elements: 565
#
# Direction 2
# Shape: (241, 241)
# Sum: 0.9999999999999998
# Non-zero elements: 559
#
# Direction 3
# Shape: (241, 241)
# Sum: 1.0
# Non-zero elements: 552
#
# Are direction 0 and direction 1 identical? False
# right trial LE: -6.3201781815086155
# right GLCM[0] sum: 1.0
# right GLCM[0] nonzero: 552
# Direction: right
# Current ROI pixels: 282
# New pixels: 25
# Trial ROI pixels: 307
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 244, 244, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (244, 244)
# Sum: 1.0
# Non-zero elements: 552
#
# Direction 1
# Shape: (244, 244)
# Sum: 1.0
# Non-zero elements: 565
#
# Direction 2
# Shape: (244, 244)
# Sum: 0.9999999999999999
# Non-zero elements: 559
#
# Direction 3
# Shape: (244, 244)
# Sum: 1.0
# Non-zero elements: 554
#
# Are direction 0 and direction 1 identical? False
# left trial LE: -6.32140716587131
# left GLCM[0] sum: 1.0
# left GLCM[0] nonzero: 552
# Direction: left
# Current ROI pixels: 282
# New pixels: 25
# Trial ROI pixels: 307
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 238, 238, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (238, 238)
# Sum: 1.0
# Non-zero elements: 548
#
# Direction 1
# Shape: (238, 238)
# Sum: 1.0
# Non-zero elements: 567
#
# Direction 2
# Shape: (238, 238)
# Sum: 1.0
# Non-zero elements: 555
#
# Direction 3
# Shape: (238, 238)
# Sum: 1.0
# Non-zero elements: 548
#
# Are direction 0 and direction 1 identical? False
# Direction: down
# Current ROI pixels: 282
# New pixels: 23
# Trial ROI pixels: 305
# Type of P_glcm: <class 'numpy.ndarray'>
# Shape of P_glcm: (1, 241, 241, 4)
# Number of dimensions: 4
#
# Direction 0
# Shape: (241, 241)
# Sum: 1.0
# Non-zero elements: 548
#
# Direction 1
# Shape: (241, 241)
# Sum: 1.0
# Non-zero elements: 565
#
# Direction 2
# Shape: (241, 241)
# Sum: 1.0
# Non-zero elements: 555
#
# Direction 3
# Shape: (241, 241)
# Sum: 0.9999999999999999
# Non-zero elements: 546
#
# Are direction 0 and direction 1 identical? False
# Direction: up
# Current ROI pixels: 282
# New pixels: 23
# Trial ROI pixels: 305
# Iter  5: ROI  282 ->  282 | Accepted dirs: 0 | Active dirs: 0 | New pixels:    0
#
# ✓ Iterative directional growing completed!
# Stopping reason: No accepted directional expansion in this iteration
#
# Iteration summary:
#  Iteration  ROI Size Before  ROI Size After   Accepted Directions   Rejected Directions  Active Directions  New Pixels Added  ROI LE After  Relative Difference From ROI0   ROI0_LE
#          1               76             129 right, left, down, up                  None                  4                53     -5.368609                       0.153076 -4.655901
#          2              129             178 right, left, down, up                  None                  4                49     -5.736239                       0.232036 -4.655901
#          3              178             228 right, left, down, up                  None                  4                50     -6.003585                       0.289457 -4.655901
#          4              228             282 right, left, down, up                  None                  4                54     -6.230186                       0.338127 -4.655901
#          5              282             282                  None right, left, down, up                  0                 0           NaN                            NaN -4.655901
#
# Directional evaluation summary (first rows):
#  Iteration Direction  Accepted  Deactivated                               Deactivation Reason   ROI0_LE  Trial LE  Relative Difference  Directional GLCM Count  New Pixels
#          1     right      True        False                                              None -4.655901 -4.917775             0.056245                       4          17
#          1      left      True        False                                              None -4.655901 -4.917775             0.056245                       4          17
#          1      down      True        False                                              None -4.655901 -5.022381             0.078713                       4          21
#          1        up      True        False                                              None -4.655901 -5.020071             0.078217                       4          21
#          2     right      True        False                                              None -4.655901 -5.525721             0.186821                       4          19
#          2      left      True        False                                              None -4.655901 -5.525721             0.186821                       4          19
#          2      down      True        False                                              None -4.655901 -5.523578             0.186361                       4          18
#          2        up      True        False                                              None -4.655901 -5.523578             0.186361                       4          18
#          3     right      True        False                                              None -4.655901 -5.858114             0.258213                       4          21
#          3      left      True        False                                              None -4.655901 -5.859082             0.258421                       4          21
#          3      down      True        False                                              None -4.655901 -5.850349             0.256545                       4          19
#          3        up      True        False                                              None -4.655901 -5.847406             0.255913                       4          19
#          4     right      True        False                                              None -4.655901 -6.107874             0.311856                       4          23
#          4      left      True        False                                              None -4.655901 -6.107874             0.311856                       4          23
#          4      down      True        False                                              None -4.655901 -6.101092             0.310400                       4          21
#          4        up      True        False                                              None -4.655901 -6.098782             0.309904                       4          21
#          5     right     False         True Relative difference reached or exceeded threshold -4.655901 -6.320178             0.357455                       4          25
#          5      left     False         True Relative difference reached or exceeded threshold -4.655901 -6.321407             0.357719                       4          25
#          5      down     False         True Relative difference reached or exceeded threshold -4.655901 -6.315936             0.356544                       4          23
#          5        up     False         True Relative difference reached or exceeded threshold -4.655901 -6.313474             0.356015                       4          23

# %% [markdown]
# ## Stage 6: Results & Visualizations

# %%
# Results summary table
print("\n" + "="*90)
print("DIRECTIONAL LOCAL ENTROPY REGION GROWING RESULTS")
print("="*90)
print(df_results.to_string(index=False))
print("="*90)

# Summary statistics
roi_initial = mask0.copy()
roi_final = roi_final.copy()
total_growth = int(roi_final.sum() - roi_initial.sum())
percent_growth = (total_growth / roi_initial.sum()) * 100 if roi_initial.sum() else np.nan
final_roi_le = iteration_history[-1]["roi_after_le"] if iteration_history else np.nan
final_relative_difference = iteration_history[-1]["relative_difference_from_roi0"] if iteration_history else np.nan

print(f"\nFinal Summary:")
print(f"  - Feature label: {FEATURE_NAME}")
print(f"  - Growth strategy: {GROWING_METHOD}")
print(f"  - Acceptance rule: relative difference < {LE_RELATIVE_THRESHOLD:.4f}")
print(f"  - ROI0 voxels: {roi_initial.sum()} voxels")
print(f"  - Final ROI size: {roi_final.sum()} voxels")
print(f"  - Total voxels added: {total_growth} voxels ({percent_growth:.1f}% growth)")
print(f"  - Max iterations: {MAX_DILATIONS}")
print(f"  - Stopping reason: {stopping_reason}")
print(f"  - ROI0_LE: {ROI0_LE:.6f}")
print(f"  - Final ROI LE: {final_roi_le:.6f}")
print(f"  - Final relative difference from ROI0_LE: {final_relative_difference:.6f}")
print(f"  - Accepted directional evaluations: {int(df_directional_results['Accepted'].sum())}")
print(f"  - Permanently deactivated directions: {int(df_directional_results['Deactivated'].sum())}")
# Out:
# ==========================================================================================
# DIRECTIONAL LOCAL ENTROPY REGION GROWING RESULTS
# ==========================================================================================
#  Iteration  ROI Size Before  ROI Size After   Accepted Directions   Rejected Directions  Active Directions  New Pixels Added  ROI LE After  Relative Difference From ROI0   ROI0_LE
#          1               76             129 right, left, down, up                  None                  4                53     -5.368609                       0.153076 -4.655901
#          2              129             178 right, left, down, up                  None                  4                49     -5.736239                       0.232036 -4.655901
#          3              178             228 right, left, down, up                  None                  4                50     -6.003585                       0.289457 -4.655901
#          4              228             282 right, left, down, up                  None                  4                54     -6.230186                       0.338127 -4.655901
#          5              282             282                  None right, left, down, up                  0                 0           NaN                            NaN -4.655901
# ==========================================================================================
#
# Final Summary:
#   - Feature label: LocalEntropy
#   - Growth strategy: directional
#   - Acceptance rule: relative difference < 0.3500
#   - ROI0 voxels: 76 voxels
#   - Final ROI size: 282 voxels
#   - Total voxels added: 206 voxels (271.1% growth)
#   - Max iterations: 20
#   - Stopping reason: No accepted directional expansion in this iteration
#   - ROI0_LE: -4.655901
#   - Final ROI LE: nan
#   - Final relative difference from ROI0_LE: nan
#   - Accepted directional evaluations: 16
#   - Permanently deactivated directions: 4

# %%
# Visualization: Final ROI evolution
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Plot 1: Original image with initial mask
axes[0].imshow(roi_img, cmap="gray", vmin=0, vmax=np.percentile(roi_img, 99))
axes[0].contour(mask0, colors='r', linewidths=2.5)
axes[0].set_title(f"Initial ROI0\n({mask0.sum()} voxels)", fontsize=12, fontweight='bold')
axes[0].axis('off')

# Plot 2: Original image with final ROI
axes[1].imshow(roi_img, cmap="gray", vmin=0, vmax=np.percentile(roi_img, 99))
axes[1].contour(roi_final, colors='g', linewidths=2.5)
axes[1].set_title(f"Final ROI after {MAX_DILATIONS} iterations\n({roi_final.sum()} voxels)", fontsize=12, fontweight='bold')
axes[1].axis('off')

# Plot 3: ROI size and LE evolution
iteration_range = np.array([record["iteration"] for record in iteration_history])
roi_sizes_after = np.array([record["roi_size_after"] for record in iteration_history], dtype=float)
roi_le_after = np.array([record["roi_after_le"] for record in iteration_history], dtype=float)
relative_differences = np.array([record["relative_difference_from_roi0"] for record in iteration_history], dtype=float)
accepted_counts = np.array([record["accepted_direction_count"] for record in iteration_history], dtype=float)

axes[2].plot(iteration_range, roi_sizes_after, 'o-', linewidth=2, markersize=6, color='darkgreen', label='ROI size after')
axes[2].set_xlabel("Iteration")
axes[2].set_ylabel("ROI size (voxels)", color='darkgreen')
axes[2].tick_params(axis='y', labelcolor='darkgreen')
axes[2].grid(alpha=0.3)

ax2 = axes[2].twinx()
ax2.plot(iteration_range, roi_le_after, 's--', linewidth=2, markersize=5, color='darkorange', label='ROI LE after')
ax2.axhline(ROI0_LE, color='crimson', linestyle='--', linewidth=1.8, alpha=0.8, label='ROI0_LE')
ax2.set_ylabel("Local Entropy", color='darkorange')
ax2.tick_params(axis='y', labelcolor='darkorange')

axes[2].set_title("ROI growth and Local Entropy evolution", fontsize=12, fontweight='bold')

lines1, labels1 = axes[2].get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
axes[2].legend(lines1 + lines2, labels1 + labels2, loc='best', fontsize=9)

plt.tight_layout()
plt.show()

# Convergence diagnostics
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

axes[0, 0].bar(iteration_range, accepted_counts, color='steelblue', alpha=0.9)
axes[0, 0].set_title("Accepted Directions per Iteration", fontweight='bold')
axes[0, 0].set_xlabel("Iteration")
axes[0, 0].set_ylabel("Accepted directions")
axes[0, 0].grid(alpha=0.3, axis='y')

axes[0, 1].plot(iteration_range, roi_sizes_after, 'o-', color='darkgreen', linewidth=2, markersize=6)
axes[0, 1].set_title("Cumulative ROI Size", fontweight='bold')
axes[0, 1].set_xlabel("Iteration")
axes[0, 1].set_ylabel("ROI size (voxels)")
axes[0, 1].grid(alpha=0.3)

axes[1, 0].plot(iteration_range, roi_le_after, 'o-', color='navy', linewidth=2, markersize=6, label='ROI LE after')
axes[1, 0].axhline(ROI0_LE, color='r', linestyle='--', linewidth=2, label='ROI0_LE')
axes[1, 0].set_title("ROI Local Entropy evolution", fontweight='bold')
axes[1, 0].set_xlabel("Iteration")
axes[1, 0].set_ylabel("Local Entropy")
axes[1, 0].legend()
axes[1, 0].grid(alpha=0.3)

axes[1, 1].plot(iteration_range, relative_differences, 'o-', color='darkorange', linewidth=2, markersize=6, label='Relative difference')
axes[1, 1].axhline(LE_RELATIVE_THRESHOLD, color='black', linestyle='--', linewidth=2, label='Threshold')
axes[1, 1].set_title("Relative difference vs ROI0_LE", fontweight='bold')
axes[1, 1].set_xlabel("Iteration")
axes[1, 1].set_ylabel("Relative difference")
axes[1, 1].legend()
axes[1, 1].grid(alpha=0.3)

fig.suptitle(f"Convergence diagnostics | Stopping reason: {stopping_reason}", fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Detailed visualization of a specific iteration (example: iteration 5)
iter_to_show = min(3, len(iteration_history))  # Show iteration 5, or last if fewer iterations
iteration_data = iteration_history[iter_to_show - 1]
direction_order = ["right", "left", "down", "up"]
direction_labels = {
    "right": "Positive X / Right",
    "left": "Negative X / Left",
    "down": "Positive Y / Down",
    "up": "Negative Y / Up",
}

fig, axes = plt.subplots(2, 3, figsize=(17, 10))

# Row 1: current ROI and horizontal growth directions
axes[0, 0].imshow(roi_img, cmap="gray", vmin=0, vmax=np.percentile(roi_img, 99))
axes[0, 0].contour(iteration_data["roi_current"], colors='cyan', linewidths=2)
axes[0, 0].set_title(
    f"Iteration {iter_to_show}: current accepted ROI\n({iteration_data['roi_size_before']} voxels)",
    fontweight='bold'
)
axes[0, 0].axis('off')

for axis, direction in zip([axes[0, 1], axes[0, 2]], ["right", "left"]):
    record = iteration_data["direction_trials"].get(direction)
    axis.imshow(roi_img, cmap="gray", vmin=0, vmax=np.percentile(roi_img, 99))
    axis.contour(record["current_roi"], colors='cyan', linewidths=1.5)
    axis.contour(record["trial_roi"], colors='white', linewidths=1.0, linestyles='--')
    if np.any(record["new_pixels"]):
        contour_color = 'lime' if record["accepted"] else 'red'
        axis.contour(record["new_pixels"], colors=contour_color, linewidths=2.5)
    axis.set_title(
        f"{direction_labels[direction]}\n"
        f"LE={record['trial_le']:.6f} | rel.diff={record['relative_difference']:.4f}",
        fontweight='bold'
    )
    axis.axis('off')

# Row 2: vertical growth directions and acceptance summary
for axis, direction in zip([axes[1, 0], axes[1, 1]], ["down", "up"]):
    record = iteration_data["direction_trials"].get(direction)
    axis.imshow(roi_img, cmap="gray", vmin=0, vmax=np.percentile(roi_img, 99))
    axis.contour(record["current_roi"], colors='cyan', linewidths=1.5)
    axis.contour(record["trial_roi"], colors='white', linewidths=1.0, linestyles='--')
    if np.any(record["new_pixels"]):
        contour_color = 'lime' if record["accepted"] else 'red'
        axis.contour(record["new_pixels"], colors=contour_color, linewidths=2.5)
    axis.set_title(
        f"{direction_labels[direction]}\n"
        f"LE={record['trial_le']:.6f} | rel.diff={record['relative_difference']:.4f}",
        fontweight='bold'
    )
    axis.axis('off')

relative_differences = []
bar_colors = []
for direction in direction_order:
    record = iteration_data["direction_trials"].get(direction)
    relative_differences.append(record["relative_difference"])
    if record["accepted"]:
        bar_colors.append('seagreen')
    elif record["deactivated"]:
        bar_colors.append('lightgray')
    else:
        bar_colors.append('salmon')

axes[1, 2].bar(direction_order, relative_differences, color=bar_colors, edgecolor='k')
axes[1, 2].axhline(LE_RELATIVE_THRESHOLD, color='black', linestyle='--', linewidth=2, label='Threshold')
axes[1, 2].set_title("Directional relative differences", fontweight='bold')
axes[1, 2].set_ylabel("Relative difference")
axes[1, 2].set_ylim(0, max(LE_RELATIVE_THRESHOLD * 1.5, np.nanmax(relative_differences) * 1.2 if np.any(np.isfinite(relative_differences)) else 1.0))
axes[1, 2].grid(alpha=0.3, axis='y')
axes[1, 2].legend()

plt.tight_layout()
plt.show()

# Direction-by-direction summary for the selected iteration
direction_summary_rows = []
for direction in direction_order:
    record = iteration_data["direction_trials"].get(direction)
    direction_summary_rows.append({
        "Direction": direction,
        "Accepted": record["accepted"],
        "Deactivated": record["deactivated"],
        "Reason": record["deactivation_reason"],
        "Trial LE": record["trial_le"],
        "Relative Difference": record["relative_difference"],
        "New Pixels": int(record["new_pixels"].sum()),
        "Directional GLCM Count": record["glcm_matrix_count"],
    })

direction_summary_df = pd.DataFrame(direction_summary_rows)
print("\nSelected iteration summary:")
print(direction_summary_df.to_string(index=False))
print(f"\nCurrent ROI size: {iteration_data['roi_size_before']} voxels")
print(f"Next ROI size: {iteration_data['roi_size_after']} voxels")
print(f"ROI LE after iteration: {iteration_data['roi_after_le']:.6f}")
print(f"Relative difference from ROI0_LE: {iteration_data['relative_difference_from_roi0']:.6f}")

# Convergence diagnostics
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

accepted_voxels = np.array([record["accepted_direction_count"] for record in iteration_history], dtype=float)
cumulative_size = np.array([record["roi_size_after"] for record in iteration_history], dtype=float)
roi_le_after = np.array([record["roi_after_le"] for record in iteration_history], dtype=float)
metric_threshold = LE_RELATIVE_THRESHOLD
metric_relative_difference = np.array([record["relative_difference_from_roi0"] for record in iteration_history], dtype=float)

axes[0, 0].bar(iteration_range, accepted_voxels, color='steelblue', alpha=0.9)
axes[0, 0].set_title("Accepted Directions per Iteration", fontweight='bold')
axes[0, 0].set_xlabel("Iteration")
axes[0, 0].set_ylabel("Accepted directions")
axes[0, 0].grid(alpha=0.3, axis='y')

axes[0, 1].plot(iteration_range, cumulative_size, 'o-', color='darkgreen', linewidth=2, markersize=6)
axes[0, 1].set_title("Cumulative ROI Size", fontweight='bold')
axes[0, 1].set_xlabel("Iteration")
axes[0, 1].set_ylabel("ROI size (voxels)")
axes[0, 1].grid(alpha=0.3)

axes[1, 0].plot(iteration_range, roi_le_after, 'o-', color='navy', linewidth=2, markersize=6, label='ROI LE after')
axes[1, 0].axhline(ROI0_LE, color='r', linestyle='--', linewidth=2, label='ROI0_LE')
axes[1, 0].set_title("ROI Local Entropy evolution", fontweight='bold')
axes[1, 0].set_xlabel("Iteration")
axes[1, 0].set_ylabel("Local Entropy")
axes[1, 0].legend()
axes[1, 0].grid(alpha=0.3)

axes[1, 1].plot(iteration_range, metric_relative_difference, 'o-', color='darkorange', linewidth=2, markersize=6, label='Relative difference')
axes[1, 1].axhline(metric_threshold, color='black', linestyle='--', linewidth=2, label='Threshold')
axes[1, 1].set_title("Relative difference vs ROI0_LE", fontweight='bold')
axes[1, 1].set_xlabel("Iteration")
axes[1, 1].set_ylabel("Relative difference")
axes[1, 1].legend()
axes[1, 1].grid(alpha=0.3)

fig.suptitle(f"Convergence diagnostics | Stopping reason: {stopping_reason}", fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# Selected iteration summary:
# Direction  Accepted  Deactivated Reason  Trial LE  Relative Difference  New Pixels  Directional GLCM Count
#     right      True        False   None -5.858114             0.258213          21                       4
#      left      True        False   None -5.859082             0.258421          21                       4
#      down      True        False   None -5.850349             0.256545          19                       4
#        up      True        False   None -5.847406             0.255913          19                       4
#
# Current ROI size: 178 voxels
# Next ROI size: 228 voxels
# ROI LE after iteration: -6.003585
# Relative difference from ROI0_LE: 0.289457

# %% [markdown]
# ## Stage 7: Comparison with manual segmentation

# %%
# ==============================================================================
# Stage 7.1: Basic Overlap Analysis
# ==============================================================================

manual = manual_mask_roi.astype(bool)
auto = roi_final.astype(bool)

TP = np.logical_and(manual, auto).sum()
FP = np.logical_and(~manual, auto).sum()
FN = np.logical_and(manual, ~auto).sum()
TN = np.logical_and(~manual, ~auto).sum()

print("="*60)
print("OVERLAP ANALYSIS")
print("="*60)

print(f"Manual voxels:     {manual.sum()}")
print(f"Automatic voxels:  {auto.sum()}")

print()
print(f"TP: {TP}")
print(f"FP: {FP}")
print(f"FN: {FN}")
print(f"TN: {TN}")
# Out:
# ============================================================
# OVERLAP ANALYSIS
# ============================================================
# Manual voxels:     318
# Automatic voxels:  282
#
# TP: 237
# FP: 45
# FN: 81
# TN: 8801

# %%
# ==============================================================================
# Visual overlap map
# ==============================================================================

overlap = np.zeros_like(manual, dtype=np.uint8)

overlap[manual & auto] = 3      # TP
overlap[~manual & auto] = 2     # FP
overlap[manual & ~auto] = 1     # FN

plt.figure(figsize=(8,8))

plt.imshow(overlap)

plt.title(
    "Overlap Map\n"
    "1=FN  2=FP  3=TP"
)

plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(8,8))

plt.imshow(
    roi_img,
    cmap="gray",
    vmin=0,
    vmax=np.percentile(roi_img,99)
)

plt.contour(
    manual,
    colors="lime",
    linewidths=3,
    label="Manual"
)

plt.contour(
    auto,
    colors="red",
    linewidths=2,
    label="Automatic"
)

plt.title(
    f"Manual vs Automatic\n"
    f"TP={TP}  FP={FP}  FN={FN}"
)

plt.show()
# Out:
# C:\Users\oscar\AppData\Local\Temp\ipykernel_8396\829081298.py:10: UserWarning: The following kwargs were not used by contour: 'label'
#   plt.contour(
# C:\Users\oscar\AppData\Local\Temp\ipykernel_8396\829081298.py:17: UserWarning: The following kwargs were not used by contour: 'label'
#   plt.contour(

# %%
dice = (2 * TP) / (2 * TP + FP + FN)

iou = TP / (TP + FP + FN)

recall = TP / (TP + FN)

precision = TP / (TP + FP)

metrics_df = pd.DataFrame({
    "Metric": [
        "Dice",
        "IoU",
        "Recall",
        "Precision"
    ],
    "Value": [
        dice,
        iou,
        recall,
        precision
    ]
})

print(f"Final Dice coefficient: {dice:.4f}")

metrics_df
# Out:
# Final Dice coefficient: 0.7900
#       Metric     Value
# 0       Dice  0.790000
# 1        IoU  0.652893
# 2     Recall  0.745283
# 3  Precision  0.840426
